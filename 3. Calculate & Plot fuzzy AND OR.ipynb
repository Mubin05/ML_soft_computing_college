# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
n = int(input("Enter count of fuzzy member in set = "))

# creating arrays for member and membership function / grade

fmember = [100+member for member in range(1, n+1)]
fgradeA = [np.random.random() for i in range(n)]
fgradeB = [np.random.random() for i in range(n)]

print()
print("Fuzzy members = ")
print(fmember)
print()
print("Fuzzy set-A membership grades = ")
print(fgradeA)
print()
print("Fuzzy set-B membership grades = ")
print(fgradeB)
print()
# Out:
# Fuzzy members =
# [101, 102, 103, 104, 105, 106, 107, 108, 109, 110, 111, 112, 113, 114, 115, 116, 117, 118, 119, 120]
#
# Fuzzy set-A membership grades =
# [0.9653605231360376, 0.9323197580833632, 0.57829982968047, 0.005616031630693463, 0.7686458176255977, 0.3861529134813476, 0.021946186837431325, 0.3547638219863478, 0.3187921339540559, 0.058050531607321876, 0.08615980206613894, 0.5522871391202919, 0.5615539046999772, 0.4686708819978742, 0.9363742925354733, 0.2559861077219976, 0.7669482466806918, 0.13018980872713815, 0.5523689232476073, 0.23223940354790973]
#
# Fuzzy set-B membership grades =
# ...

# %%
plt.figure(figsize=(17,5))
plt.plot(fgradeA, marker="o", color="r", label="Membership Grade(Set-A)")

# %%
plt.figure(figsize=(17,5))
plt.plot(fgradeB, marker="o", color="g", label="Membership Grade(Set-B)")

# %%
union=list()
for i in range(n):
    union.append(max(fgradeA[i], fgradeB[i]))
print("Fuzzy Set-A OR Fuzzy Set-B = ")
print(union)
print()
# Out:
# Fuzzy Set-A OR Fuzzy Set-B =
# [0.9653605231360376, 0.9323197580833632, 0.57829982968047, 0.12261421051595278, 0.8868698791350801, 0.3861529134813476, 0.42923015944641363, 0.8884483213456418, 0.3187921339540559, 0.09872209975168, 0.35756776080418184, 0.5522871391202919, 0.5615539046999772, 0.8648243524384148, 0.9363742925354733, 0.7871121343950823, 0.7669482466806918, 0.805083144180215, 0.5523689232476073, 0.23223940354790973]

# %%
intersect =list()
for i in range(n):
    intersect.append(min(fgradeA[i], fgradeB[i]))
print("Fuzzy Set-A AND Fuzzy Set-B = ")
print(intersect)
print()
# Out:
# Fuzzy Set-A AND Fuzzy Set-B =
# [0.4952162314372357, 0.8486817702221378, 0.025957671260501636, 0.005616031630693463, 0.7686458176255977, 0.37691660410251515, 0.021946186837431325, 0.3547638219863478, 0.12842409294407253, 0.058050531607321876, 0.08615980206613894, 0.11435767153521059, 0.3897097043246419, 0.4686708819978742, 0.44047678987709105, 0.2559861077219976, 0.43825980142185317, 0.13018980872713815, 0.4457517160805129, 0.14676112172977263]

# %%
# plotting UNION with all membership grades

plt.figure(figsize=(17,5))
# plt.plot(fgradeA, marker="o", color="r", label="Membership Grade(Set-A)")
# plt.plot(fgradeB, marker="o", color="g", label="Membership Grade(Set-B)")
plt.plot(union, marker="o", color="b", label="UNION(Set-A, Set-B)")
plt.xlabel('x')
plt.ylabel('Membership Value')
plt.title('Fuzzy Sets and Operations')
plt.grid(True)
plt.show()

# %%
# plotting INTERSECTION with all membership grades

plt.figure(figsize=(15,8))
# plt.plot(fgradeA, marker="o", color="r", label="Membership Grade(Set-A)")
# plt.plot(fgradeB, marker="o", color="g", label="Membership Grade(Set-B)")
plt.plot(intersect, marker="o", color="b" )
plt.xlabel('x')
plt.ylabel('Membership Value')
plt.title('Fuzzy Sets and Operations')
plt.grid(True)
plt.show()
