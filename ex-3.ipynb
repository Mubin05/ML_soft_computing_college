# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
n = int(input("Enter count of fuzzy member in set = "))

# creating arrays for member and membership function / grade

fmember = [100+member for member in range(1, n+1)]
fgradeA = [np.random.random() for i in range(n)]
fgradeB = [np.random.random() for i in range(n)]

print()
print("Fuzzy members = ")
print(fmember)
print()
print("Fuzzy set-A membership grades = ")
print(fgradeA)
print()
print("Fuzzy set-B membership grades = ")
print(fgradeB)
print()
# Out:
# Fuzzy members =
# [101, 102, 103, 104, 105, 106, 107, 108, 109, 110, 111, 112, 113, 114, 115, 116, 117, 118, 119, 120, 121, 122, 123, 124, 125, 126, 127, 128, 129, 130]
#
# Fuzzy set-A membership grades =
# [0.5221211826476768, 0.8072627786175175, 0.42148202021407166, 0.7440631083962376, 0.1732831257748475, 0.6006185923181906, 0.5109410074197126, 0.5594035113719652, 0.6695321036431526, 0.6424259695111904, 0.08355472164043587, 0.30839896125470945, 0.4899724310582465, 0.3629633612400881, 0.9254833708375181, 0.6145137575449089, 0.5549798324426086, 0.38983368987609346, 0.7908543176189772, 0.06222495071977663, 0.6172488896993915, 0.8999390418545508, 0.5311434497905372, 0.17425472856496782, 0.32554712886232673, 0.49772527269255307, 0.13055939702503105, 0.011689411055550436, 0.9016602315863949, 0.4594091808430334]
#
# Fuzzy set-B membership grades =
# [0.6471096055809656, 0.16786865105106286, 0.32505691958937544, 0.031184724060200453, 0.8287360009006743, 0.2769468356890815, 0.04165473193196623, 0.4127085063832423, 0.29755188638704033, 0.46602588955311686, 0.5174190333544073, 0.39385137603758813, 0.8757405103046078, 0.06292441807773508, 0.1686218631330193, 0.38562472915605306, 0.5727877812094343, 0.14947576409299668, 0.6804325309815624, 0.14993437268999765, 0.9129579154836576, 0.8616937042598696, 0.24351604599128263, 0.1543665979128267, 0.4860693343484648, 0.11194786053931072, 0.17217538062960602, 0.7298339667083357, 0.18831047643442056, 0.8306823376474413]

# %%
plt.figure(figsize=(3,4))
plt.plot(fgradeA, marker="o", color="r", label="Membership Grade(Set-A)")

# %%
plt.figure(figsize=(3,4))
plt.plot(fgradeB, marker="o", color="g", label="Membership Grade(Set-B)")

# %%
union=list()
for i in range(n):
    union.append(max(fgradeA[i], fgradeB[i]))
print("Fuzzy Set-A OR Fuzzy Set-B = ")
print(union)
print()
# Out:
# Fuzzy Set-A OR Fuzzy Set-B =
# [0.6471096055809656, 0.8072627786175175, 0.42148202021407166, 0.7440631083962376, 0.8287360009006743, 0.6006185923181906, 0.5109410074197126, 0.5594035113719652, 0.6695321036431526, 0.6424259695111904, 0.5174190333544073, 0.39385137603758813, 0.8757405103046078, 0.3629633612400881, 0.9254833708375181, 0.6145137575449089, 0.5727877812094343, 0.38983368987609346, 0.7908543176189772, 0.14993437268999765, 0.9129579154836576, 0.8999390418545508, 0.5311434497905372, 0.17425472856496782, 0.4860693343484648, 0.49772527269255307, 0.17217538062960602, 0.7298339667083357, 0.9016602315863949, 0.8306823376474413]

# %%
intersect =list()
for i in range(n):
    intersect.append(min(fgradeA[i], fgradeB[i]))
print("Fuzzy Set-A AND Fuzzy Set-B = ")
print(intersect)
print()
# Out:
# Fuzzy Set-A AND Fuzzy Set-B =
# [0.5221211826476768, 0.16786865105106286, 0.32505691958937544, 0.031184724060200453, 0.1732831257748475, 0.2769468356890815, 0.04165473193196623, 0.4127085063832423, 0.29755188638704033, 0.46602588955311686, 0.08355472164043587, 0.30839896125470945, 0.4899724310582465, 0.06292441807773508, 0.1686218631330193, 0.38562472915605306, 0.5549798324426086, 0.14947576409299668, 0.6804325309815624, 0.06222495071977663, 0.6172488896993915, 0.8616937042598696, 0.24351604599128263, 0.1543665979128267, 0.32554712886232673, 0.11194786053931072, 0.13055939702503105, 0.011689411055550436, 0.18831047643442056, 0.4594091808430334]

# %%
# plotting UNION with all membership grades

plt.figure(figsize=(3,4))
# plt.plot(fgradeA, marker="o", color="r", label="Membership Grade(Set-A)")
# plt.plot(fgradeB, marker="o", color="g", label="Membership Grade(Set-B)")
plt.plot(union, marker="o", color="b", label="UNION(Set-A, Set-B)")
plt.xlabel('x')
plt.ylabel('Membership Value')
plt.title('Fuzzy Sets OR Operations')
plt.grid(True)
plt.show()

# %%
# plotting INTERSECTION with all membership grades

plt.figure(figsize=(3,4))
# plt.plot(fgradeA, marker="o", color="r", label="Membership Grade(Set-A)")
# plt.plot(fgradeB, marker="o", color="g", label="Membership Grade(Set-B)")
plt.plot(intersect, marker="o", color="orange" )
plt.xlabel('x')
plt.ylabel('Membership Value')
plt.title('Fuzzy Sets AND Operations')
plt.grid(True)
plt.show()
