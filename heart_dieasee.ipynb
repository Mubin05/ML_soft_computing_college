# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from ucimlrepo import fetch_ucirepo

# %%
  
# fetch dataset 
heart_disease = fetch_ucirepo(id=45) 
  
mean = X.mean()
median = X.median()
mode = X.mode().iloc[0]  # Only the first mode (in case there are multiple modes
  
print("Mean:\n", mean)
print("Median:\n", median)
print("Mode:\n", mode)
# Out:
# Mean:
#  age          54.438944
# sex           0.679868
# cp            3.158416
# trestbps    131.689769
# chol        246.693069
# fbs           0.148515
# restecg       0.990099
# thalach     149.607261
# exang         0.326733
# oldpeak       1.039604
# slope         1.600660
# ca            0.672241
# thal          4.734219
# dtype: float64
# Median:
#  age          56.0
# sex           1.0
# cp            3.0
# trestbps    130.0
# chol        241.0
# fbs           0.0
# restecg       1.0
# thalach     153.0
# exang         0.0
# oldpeak       0.8
# slope         2.0
# ca            0.0
# thal          3.0
# dtype: float64
# Mode:
#  age          58.0
# sex           1.0
# cp            4.0
# trestbps    120.0
# chol        197.0
# fbs           0.0
# restecg       0.0
# thalach     162.0
# exang         0.0
# oldpeak       0.0
# slope         1.0
# ca            0.0
# thal          3.0
# Name: 0, dtype: float64

# %%
# Plot mean
plt.figure(figsize=(10, 6))
plt.bar(X.columns, mean, color='skyblue')
plt.title('Mean of Each Feature in Heart Disease Dataset')
plt.xlabel('Features')
plt.ylabel('Mean')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Plot median
plt.figure(figsize=(10, 6))
plt.bar(X.columns, median, color='lightgreen')
plt.title('Median of Each Feature in Heart Disease Dataset')
plt.xlabel('Features')
plt.ylabel('Median')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Plot mode
plt.figure(figsize=(10, 6))
plt.bar(X.columns, mode, color='salmon')
plt.title('Mode of Each Feature in Heart Disease Dataset')
plt.xlabel('Features')
plt.ylabel('Mode')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
