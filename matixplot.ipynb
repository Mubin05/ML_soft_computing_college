# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import kurtosis, skew

# %%
matrix = np.random.random((100, 100))

# %%
means = np.mean(matrix, axis=0)         # Mean of each column
variances = np.var(matrix, axis=0)      # Variance of each column
kurtoses = kurtosis(matrix, axis=0)     # Kurtosis of each column
skewnesses = skew(matrix, axis=0)       # Skewness of each column

# %%
print("Mean = ")
print(means)
print()
print("Variens = ")
print(variances)
print()
print("Skewness = ")
print(skewnesses)
print()
print("Kurtosis = ")
print(kurtoses)
print()
# Out:
# Mean =
# [0.45768537 0.51985758 0.49366331 0.49771419 0.45538532 0.51361012
#  0.46728642 0.50751371 0.50940925 0.43689306 0.55238184 0.50583718
#  0.52642588 0.48049816 0.5219696  0.50754427 0.48858116 0.51589286
#  0.47072988 0.55522955 0.42196566 0.52344602 0.54789162 0.48132377
#  0.47582409 0.51283551 0.48795021 0.53549384 0.50212669 0.50883195
#  0.46084199 0.50351409 0.46199785 0.53236478 0.50485281 0.5314863
#  0.48017913 0.52547684 0.50841758 0.51254242 0.54449271 0.49554544
#  0.50597656 0.47795226 0.49511171 0.49867245 0.48849847 0.50592974
#  0.51105209 0.51478982 0.45804786 0.55058155 0.52369189 0.5200357
#  0.52706803 0.49286815 0.49258009 0.48272342 0.49145468 0.46150693
#  0.50141318 0.53249631 0.48920861 0.47621522 0.50299492 0.50658683
#  0.49687019 0.45436037 0.52348871 0.49539599 0.49613208 0.4930623
#  0.49293621 0.51993656 0.50491959 0.52779029 0.5071702  0.47167705
#  0.51905392 0.53607248 0.48373815 0.52123928 0.48871229 0.48783767
#  0.48915062 0.50200167 0.50092785 0.52465528 0.56889898 0.49841967
#  0.53478833 0.50205556 0.48484992 0.50720041 0.5056695  0.52923307
#  0.47288226 0.49992654 0.45432132 0.43197845]
#
# Variens =
# [0.09610147 0.09062996 0.0829026  0.08385782 0.08281219 0.087431
#  0.07827428 0.08911891 0.07155281 0.07114246 0.08428586 0.07185308
#  0.08154011 0.07670575 0.07286687 0.0884245  0.08763114 0.07357909
#  0.07572656 0.09064379 0.08702989 0.08286024 0.08855484 0.09924399
#  0.0753236  0.08849579 0.09326633 0.07205386 0.08386079 0.08914361
#  0.08274368 0.07816986 0.08547569 0.07906449 0.0694035  0.08945375
#  0.07627748 0.09248636 0.08080706 0.07732274 0.08567818 0.08789603
#  0.09152469 0.07833825 0.08016898 0.09428997 0.07883143 0.09038209
#  0.08914923 0.07494296 0.08144536 0.08260302 0.09701934 0.08223766
#  0.08745807 0.07224634 0.09049533 0.07507334 0.08085498 0.08089582
#  0.08740342 0.09115131 0.07704234 0.0807278  0.080452   0.07435454
#  0.07864314 0.08482869 0.08489794 0.08582831 0.08293413 0.07504984
#  0.08168654 0.07557449 0.09101806 0.08000511 0.08541501 0.07597815
#  0.08269059 0.08122139 0.08876394 0.10111025 0.08163393 0.07055366
#  0.08273201 0.08499406 0.07915229 0.08036665 0.08113011 0.08264223
#  0.0713272  0.08247546 0.08485775 0.08371541 0.07319706 0.0878838
#  0.08814553 0.08066426 0.08351789 0.08878702]
#
# Skewness =
# [ 0.20522054 -0.07824875  0.11627634 -0.00849882  0.16576364  0.10674478
#   0.1217773  -0.11446376 -0.09810402  0.20333556 -0.19097179  0.12867853
#  -0.11245693  0.20824063 -0.12758321 -0.04973558  0.11669189 -0.10395713
#   0.10611932 -0.37401197  0.48357744 -0.14684729 -0.29585867 -0.06494487
#   0.22037599 -0.11651754  0.08695339 -0.05521375 -0.01112375  0.05395862
#   0.17419313  0.03284175  0.13728814  0.05267916 -0.17111459 -0.16958209
#   0.1881891  -0.02889419  0.03632679 -0.06842506 -0.24870197 -0.05374953
#  -0.05059796  0.10500736 -0.04617621  0.01618448  0.18547436 -0.01027656
#   0.10307135 -0.17035754  0.12024661 -0.21204376 -0.19128414 -0.10597344
#  -0.1269157   0.16238344 -0.01028756  0.10133068  0.04950099  0.10076117
#  -0.07274823 -0.17513908  0.01160504  0.09152187 -0.1626719   0.03301573
#   0.122788    0.25398234 -0.15196584 -0.10194445 -0.04923098 -0.07297161
#   0.04057665 -0.06492251 -0.05620888 -0.08666723  0.02444713  0.09926336
#  -0.10601512 -0.19652744  0.15174094 -0.07789991  0.18922655  0.01367914
#   0.03649628 -0.05589004  0.00394047  0.00333576 -0.43804914 -0.02553903
#  -0.19264582  0.14382739  0.06632861  0.12170361  0.11975196 -0.04951874
#  -0.01908952  0.00367708  0.18565471  0.15389155]
#
# Kurtosis =
# [-1.30124026 -1.25584161 -1.28372627 -1.24202944 -1.24084585 -1.2708214
#  -1.23989186 -1.27249207 -1.04808353 -1.16018829 -1.18561047 -1.13626219
#  -1.20376225 -1.00041656 -1.11761755 -1.26184195 -1.27097991 -1.02711163
#  -1.0452125  -1.15447995 -1.01527597 -1.16775005 -1.14477441 -1.39648648
#  -1.05027987 -1.15908522 -1.25767631 -1.16203292 -1.08850436 -1.13213225
#  -1.25285721 -1.17401837 -1.27418723 -1.21198468 -1.14340703 -1.2544424
#  -1.10308857 -1.35022899 -1.22872158 -1.10306514 -1.18307715 -1.26785106
#  -1.33807955 -1.04303474 -1.16808377 -1.30198684 -1.06426328 -1.35599403
#  -1.39891397 -1.04849137 -1.13519769 -1.21773069 -1.29710885 -1.25635958
#  -1.13511257 -1.00227799 -1.21361105 -1.12207646 -1.12644074 -1.18133189
#  -1.22345722 -1.27502788 -1.06093182 -1.2364149  -1.12153903 -1.22535717
#  -1.06446482 -1.16352689 -1.25932921 -1.29432751 -1.24542656 -1.02168865
#  -1.05612044 -1.06495225 -1.41404412 -1.19161317 -1.28760553 -1.14305169
#  -1.22730942 -1.15845718 -1.21357199 -1.39667107 -1.15023332 -0.99003051
#  -1.22332674 -1.15326489 -1.12787632 -1.19559806 -0.83846887 -1.16436579
#  -1.01585745 -1.11268311 -1.13673295 -1.13442834 -1.04104657 -1.31496733
#  -1.32996326 -1.15689156 -1.11643266 -1.29853892]

# %%
# Plot Mean
plt.figure(figsize=(15, 5))
plt.plot(means,color='red',marker="o")
plt.title('Mean of Each Column')
plt.xlabel('Column Index')
plt.ylabel('Mean')
plt.tight_layout()
plt.show()

# %%
# Plot Variance
plt.figure(figsize=(15, 5))
plt.plot(variances,color='orange',marker="o")
plt.title('Variance of Each Column')
plt.xlabel('Column Index')
plt.ylabel('Variance')
plt.tight_layout()
plt.show()

# %%
# Plot Skewness
plt.figure(figsize=(15, 5))
plt.plot(skewnesses,color='green',marker="o")
plt.title('Skewness of Each Column')
plt.xlabel('Column Index')
plt.ylabel('Skewness')
plt.tight_layout()
plt.show()

# %%
# Plot Skewness
plt.figure(figsize=(15, 5))
plt.plot(skewnesses,color='black',marker="o")
plt.title('Skewness of Each Column')
plt.xlabel('Column Index')
plt.ylabel('Skewness')
plt.tight_layout()
plt.show()

# %%
# Step 4: Display the plots
plt.tight_layout()
plt.show()
